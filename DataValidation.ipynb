# %% [markdown]
# Data validation

# %% [markdown]
# (Code run on Google Colab)

# %%
import pandas as pd

# %%
# Load file
df=pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Data/BTC_perpetual_10min.csv',na_values=['null'],parse_dates=True,infer_datetime_format=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-5b33e8c5ad0a> in <module>()
#       1 # Load file
# ----> 2 df=pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Data/BTC_perpetual_10min.csv',na_values=['null'],parse_dates=True,infer_datetime_format=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#change timestamp column to datetime 
df['timestamp'] = pd.to_datetime(df['timestamp'])

#drop duplicates
df.drop_duplicates(subset=['timestamp'],
                   keep='first',
                   inplace=True)
df.reset_index(inplace=True)

keep_cols = ['volume',  
        'open', 'low', 'high','close',
       'timestamp']

for i in df.columns:
    if i in keep_cols:
        pass
    else:
        del df[i]

# %%
# Check which data should be changed
df['returns'] = df.close.pct_change()
df.dropna(inplace=True)
df.returns.plot()

# %%
# Iterate over specific short time frames and check for data to change
for i in df[62830:62860].itertuples():
    print(i.timestamp,i.close,i.open,i.low,i.high,
          i.Index)

# %%
# Change this specific data
d1 = dt.datetime(2020,3,12,10,40,0)
d2 = dt.datetime(2020,3,12,10,50,0)
d3 = dt.datetime(2020,3,12,11,00,0)

mask =  (df.timestamp==d1) | (df.timestamp==d2) \
        | (df.timestamp==d3)

# Collect all columns except timestamp in list
rel_cols = [col for col in df.columns if col != 'timestamp']

df.loc[mask, rel_cols] = np.NaN
df.fillna(method='ffill',inplace=True)

# %%
# Check for the data changed
print(df[62830:62860])
